# %%
import pandas as pd

# %%
df = pd.DataFrame([12,34,78], columns=['Values'])
print(df)
# Out:
#    Values
# 0      12
# 1      34
# 2      78

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    'Name' : ['Omer', 'Yousuf', 'Hannan' , 'Ámmar'],
    'Age' : [25, 30, 35, 40],
    'Salary' : [50000, 60000, 70000, 80000],
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Salary
# 0    Omer   25   50000
# 1  Yousuf   30   60000
# 2  Hannan   35   70000
# 3   Ámmar   40   80000

# %%
df.head(2)
# Out:
#      Name  Age  Salary
# 0    Omer   25   50000
# 1  Yousuf   30   60000

# %%
df.tail(3)
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Name': 'Full_Name'})
# Out:
#   Full_Name  Age  Salary
# 0      Omer   25   50000
# 1    Yousuf   30   60000
# 2    Hannan   35   70000
# 3     Ámmar   40   80000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   32.500000  65000.000000
# std     6.454972  12909.944487
# min    25.000000  50000.000000
# 25%    28.750000  57500.000000
# 50%    32.500000  65000.000000
# 75%    36.250000  72500.000000
# max    40.000000  80000.000000

# %%
df.to_csv('omerpandas.csv')

# %%
load_df = pd.read_csv('omerpandas.csv')
load_df
# Out:
#    Unnamed: 0    Name  Age  Salary
# 0           0    Omer   25   50000
# 1           1  Yousuf   30   60000
# 2           2  Hannan   35   70000
# 3           3   Ámmar   40   80000

# %%
df[['Name', 'Age']]
# Out:
#      Name  Age
# 0    Omer   25
# 1  Yousuf   30
# 2  Hannan   35
# 3   Ámmar   40

# %%
df.loc[df.Name == 'Omer']
# Out:
#    Name  Age  Salary
# 0  Omer   25   50000

# %%
df.iloc[0:3]
# Out:
#      Name  Age  Salary
# 0    Omer   25   50000
# 1  Yousuf   30   60000
# 2  Hannan   35   70000

# %%
df[df['Age'] > 25]
# Out:
#      Name  Age  Salary
# 1  Yousuf   30   60000
# 2  Hannan   35   70000
# 3   Ámmar   40   80000

# %%
df.loc[0:3]
# Out:
#      Name  Age  Salary
# 0    Omer   25   50000
# 1  Yousuf   30   60000
# 2  Hannan   35   70000
# 3   Ámmar   40   80000
